# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv('Crime_Hotspot_Dataset.csv')

# %%
dataset.head()
# Out:
#    Crime ID      Date & Time  Latitude  Longitude Crime Type Severity  \
# 0         1   1/2/2025 22:03   26.0337    72.2001      Theft      Low
# 1         2   1/15/2025 1:37   21.4248    76.7141    Robbery      Low
# 2         3   1/8/2025 11:00   23.1639    76.4163      Fraud     High
# 3         4  1/15/2025 17:24   29.3032    77.1843   Burglary     High
# 4         5   1/6/2025 13:42   26.8971    73.7010  Vandalism   Medium
#
#   Police Station Jurisdiction Weather  Population Density  \
# 0        West Christopherstad   Clear                9572
# 1         Lake Jeffreychester  Cloudy               18848
# 2        New Elizabethchester   Rainy               23918
# 3                Port Jessica   Clear               22502
# 4              Brandonborough  Cloudy               20035
#
#    Proximity to Landmark (meters)  ... Criminal Record Found  \
# 0                            1608  ...                  True
# 1                             796  ...                 False
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Crime ID                           1000 non-null   int64
#  1   Date & Time                        1000 non-null   object
#  2   Latitude                           1000 non-null   float64
#  3   Longitude                          1000 non-null   float64
#  4   Crime Type                         1000 non-null   object
#  5   Severity                           1000 non-null   object
#  6   Police Station Jurisdiction        1000 non-null   object
#  7   Weather                            1000 non-null   object
#  8   Population Density                 1000 non-null   int64
#  9   Proximity to Landmark (meters)     1000 non-null   int64
#  10  Time of Day                        1000 non-null   object
# ...

# %%
sns.pairplot(dataset,hue='')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-26b06705e268> in <cell line: 0>()
# ----> 1 sns.pairplot(dataset,hue='')
#
# ...
